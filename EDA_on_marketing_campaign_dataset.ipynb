# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading dataset

# %%
mar_df = pd.read_csv('marketing_data.csv')

# %%
mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0            0     6/16/14        0       189  ...                  6
# 1            0     6/15/14        0       464  ...                  7
# 2            1     5/13/14        0       134  ...                  5
# 3            1     5/11/14        0        10  ...                  2
# 4            0      4/8/14        0         6  ...                  2
# ...        ...         ...      ...       ...  ...                ...
# 2235         1      3/7/13       99       372  ...                 11
# 2236         0     1/22/13       99         5  ...                  3
# 2237         0     12/3/12       99       185  ...                  5
# 2238         0    11/29/12       99       267  ...                 10
# 2239         2      9/1/12       99       169  ...                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain  Country
# 0                0             0         1         0       SP
# 1                0             1         1         0       CA
# 2                0             0         0         0       US
# 3                0             0         0         0      AUS
# 4                0             0         1         0       SP
# ...            ...           ...       ...       ...      ...
# 2235             0             0         0         0       US
# 2236             0             0         0         0       SP
# 2237             0             0         0         0       SP
# 2238             0             0         0         0      IND
# 2239             0             0         1         0       CA
#
# [2240 rows x 28 columns]

# %%
# show all columns
pd.set_option('display.max_columns', None)

mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0     6/16/14        0       189        104              379
# 1            0     6/15/14        0       464          5               64
# 2            1     5/13/14        0       134         11               59
# 3            1     5/11/14        0        10          0                1
# 4            0      4/8/14        0         6         16               24
# ...        ...         ...      ...       ...        ...              ...
# 2235         1      3/7/13       99       372         18              126
# 2236         0     1/22/13       99         5         10               13
# 2237         0     12/3/12       99       185          2               88
# 2238         0    11/29/12       99       267         38              701
# 2239         2      9/1/12       99       169         24              553
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 111               189           218                  1
# 1                   7                 0            37                  1
# 2                  15                 2            30                  1
# 3                   0                 0             0                  1
# 4                  11                 0            34                  2
# ...               ...               ...           ...                ...
# 2235               47                48            78                  2
# 2236                3                 8            16                  1
# 2237               15                 5            14                  2
# 2238              149               165            63                  1
# 2239              188                 0           144                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain Country
# 0                0             0         1         0      SP
# 1                0             1         1         0      CA
# 2                0             0         0         0      US
# 3                0             0         0         0     AUS
# 4                0             0         1         0      SP
# ...            ...           ...       ...       ...     ...
# 2235             0             0         0         0      US
# 2236             0             0         0         0      SP
# 2237             0             0         0         0      SP
# 2238             0             0         0         0     IND
# 2239             0             0         1         0      CA
#
# [2240 rows x 28 columns]

# %% [markdown]
# ### Overview:

# %% [markdown]
# ##### The dataset contains customer information with 28 features related to a marketing campaign conducted by a company

# %%
##################################################################################################

# %% [markdown]
# ## 1.1 High-level Statistics of the Data Set

# %% [markdown]
# ### 1) Number of Data-points and Features

# %%
mar_df.shape
# Out:
# (2240, 28)

# %%
mar_df.shape[0], mar_df.shape[1]
# Out:
# (2240, 28)

# %%
mar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Response             2240 non-null   int64
#  26  Complain             2240 non-null   int64
#  27  Country              2240 non-null   object
# dtypes: int64(23), object(5)
# memory usage: 490.1+ KB

# %% [markdown]
# * The dataset contains 2240 customers' and 28 features. Each row represents data corresponding to each individual

# %%
# 28 features

list(mar_df.columns)
# Out:
# ['ID',
#  'Year_Birth',
#  'Education',
#  'Marital_Status',
#  ' Income ',
#  'Kidhome',
#  'Teenhome',
#  'Dt_Customer',
#  'Recency',
#  'MntWines',
#  'MntFruits',
#  'MntMeatProducts',
#  'MntFishProducts',
#  'MntSweetProducts',
#  'MntGoldProds',
#  'NumDealsPurchases',
#  'NumWebPurchases',
#  'NumCatalogPurchases',
#  'NumStorePurchases',
#  'NumWebVisitsMonth',
#  'AcceptedCmp3',
#  'AcceptedCmp4',
#  'AcceptedCmp5',
#  'AcceptedCmp1',
#  'AcceptedCmp2',
#  'Response',
#  'Complain',
#  'Country']

# %%
##################################################################################################

# %% [markdown]
# ## 1.2 Objective

# %% [markdown]
# * To analyse the dataset and draw useful insights about the marketing campaigns'

# %%
##################################################################################################

# %% [markdown]
# ### Data Cleaning, Manipulation and Feature Engineering

# %%
mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0     6/16/14        0       189        104              379
# 1            0     6/15/14        0       464          5               64
# 2            1     5/13/14        0       134         11               59
# 3            1     5/11/14        0        10          0                1
# 4            0      4/8/14        0         6         16               24
# ...        ...         ...      ...       ...        ...              ...
# 2235         1      3/7/13       99       372         18              126
# 2236         0     1/22/13       99         5         10               13
# 2237         0     12/3/12       99       185          2               88
# 2238         0    11/29/12       99       267         38              701
# 2239         2      9/1/12       99       169         24              553
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 111               189           218                  1
# 1                   7                 0            37                  1
# 2                  15                 2            30                  1
# 3                   0                 0             0                  1
# 4                  11                 0            34                  2
# ...               ...               ...           ...                ...
# 2235               47                48            78                  2
# 2236                3                 8            16                  1
# 2237               15                 5            14                  2
# 2238              149               165            63                  1
# 2239              188                 0           144                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain Country
# 0                0             0         1         0      SP
# 1                0             1         1         0      CA
# 2                0             0         0         0      US
# 3                0             0         0         0     AUS
# 4                0             0         1         0      SP
# ...            ...           ...       ...       ...     ...
# 2235             0             0         0         0      US
# 2236             0             0         0         0      SP
# 2237             0             0         0         0      SP
# 2238             0             0         0         0     IND
# 2239             0             0         1         0      CA
#
# [2240 rows x 28 columns]

# %%
mar_df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# min       0.000000     0.000000         0.000000         0.000000
# 25%      23.750000     1.000000        16.000000         3.000000
# 50%     173.500000     8.000000        67.000000        12.000000
# 75%     504.250000    33.000000       232.000000        50.000000
# max    1493.000000   199.000000      1725.000000       259.000000
#
#        MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# count       2240.000000   2240.000000        2240.000000      2240.000000
# mean          27.062946     44.021875           2.325000         4.084821
# std           41.280498     52.167439           1.932238         2.778714
# min            0.000000      0.000000           0.000000         0.000000
# 25%            1.000000      9.000000           1.000000         2.000000
# 50%            8.000000     24.000000           2.000000         4.000000
# 75%           33.000000     56.000000           3.000000         6.000000
# max          263.000000    362.000000          15.000000        27.000000
#
#        NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# count          2240.000000        2240.000000        2240.000000
# mean              2.662054           5.790179           5.316518
# std               2.923101           3.250958           2.426645
# min               0.000000           0.000000           0.000000
# 25%               0.000000           3.000000           3.000000
# 50%               2.000000           5.000000           6.000000
# 75%               4.000000           8.000000           7.000000
# max              28.000000          13.000000          20.000000
#
#        AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# count   2240.000000   2240.000000   2240.000000   2240.000000   2240.000000
# mean       0.072768      0.074554      0.072768      0.064286      0.013393
# std        0.259813      0.262728      0.259813      0.245316      0.114976
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#           Response     Complain
# count  2240.000000  2240.000000
# mean      0.149107     0.009375
# std       0.356274     0.096391
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max       1.000000     1.000000

# %% [markdown]
# * The describe() function gives us the 5-number statistical summary of the dataset (minimum, 25th percentile, 50th percentile(median), 75th percentile, maximum) and also the mean and standard deviation.
# * By observing the summary above, there are considerable differences between mean and median of certain features due to the presence of outliers. Also significant differences between 75th percentile and 100th percentile (max value) for some features due to the presence of extreme outliers.

# %%
mar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Response             2240 non-null   int64
#  26  Complain             2240 non-null   int64
#  27  Country              2240 non-null   object
# dtypes: int64(23), object(5)
# memory usage: 490.1+ KB

# %%
mar_df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %% [markdown]
# * column ' Income ' has extra white spaces and the datatype is an object/string

# %% [markdown]
# * removing white spaces
# * removing unnecessary characters and then converting the datatype to 'float' as 'Income' should be a number but not a string

# %%
mar_df.columns = mar_df.columns.str.replace(' ', '')
mar_df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
mar_df['Income']
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name: Income, Length: 2240, dtype: object

# %%
mar_df['Income'] = mar_df['Income'].str.replace('$', '').str.replace(',', '')

# %%
mar_df['Income']
# Out:
# 0       84835.00
# 1       57091.00
# 2       67267.00
# 3       32474.00
# 4       21474.00
#           ...
# 2235    66476.00
# 2236    31056.00
# 2237    46310.00
# 2238    65819.00
# 2239    94871.00
# Name: Income, Length: 2240, dtype: object

# %%
mar_df['Income'] = mar_df['Income'].astype('float')
mar_df['Income']
# Out:
# 0       84835.0
# 1       57091.0
# 2       67267.0
# 3       32474.0
# 4       21474.0
#          ...
# 2235    66476.0
# 2236    31056.0
# 2237    46310.0
# 2238    65819.0
# 2239    94871.0
# Name: Income, Length: 2240, dtype: float64

# %%
mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0     6/16/14        0       189        104              379
# 1            0     6/15/14        0       464          5               64
# 2            1     5/13/14        0       134         11               59
# 3            1     5/11/14        0        10          0                1
# 4            0      4/8/14        0         6         16               24
# ...        ...         ...      ...       ...        ...              ...
# 2235         1      3/7/13       99       372         18              126
# 2236         0     1/22/13       99         5         10               13
# 2237         0     12/3/12       99       185          2               88
# 2238         0    11/29/12       99       267         38              701
# 2239         2      9/1/12       99       169         24              553
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 111               189           218                  1
# 1                   7                 0            37                  1
# 2                  15                 2            30                  1
# 3                   0                 0             0                  1
# 4                  11                 0            34                  2
# ...               ...               ...           ...                ...
# 2235               47                48            78                  2
# 2236                3                 8            16                  1
# 2237               15                 5            14                  2
# 2238              149               165            63                  1
# 2239              188                 0           144                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain Country
# 0                0             0         1         0      SP
# 1                0             1         1         0      CA
# 2                0             0         0         0      US
# 3                0             0         0         0     AUS
# 4                0             0         1         0      SP
# ...            ...           ...       ...       ...     ...
# 2235             0             0         0         0      US
# 2236             0             0         0         0      SP
# 2237             0             0         0         0      SP
# 2238             0             0         0         0     IND
# 2239             0             0         1         0      CA
#
# [2240 rows x 28 columns]

# %%
mar_df['Dt_Customer']
# Out:
# 0        6/16/14
# 1        6/15/14
# 2        5/13/14
# 3        5/11/14
# 4         4/8/14
#           ...
# 2235      3/7/13
# 2236     1/22/13
# 2237     12/3/12
# 2238    11/29/12
# 2239      9/1/12
# Name: Dt_Customer, Length: 2240, dtype: object

# %% [markdown]
# * 'Dt_Customer' is stored as a string. Need to convert to datetime

# %%
mar_df['Dt_Customer'] = pd.to_datetime(mar_df['Dt_Customer'])
mar_df['Dt_Customer']
# Out:
# 0      2014-06-16
# 1      2014-06-15
# 2      2014-05-13
# 3      2014-05-11
# 4      2014-04-08
#           ...
# 2235   2013-03-07
# 2236   2013-01-22
# 2237   2012-12-03
# 2238   2012-11-29
# 2239   2012-09-01
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %% [markdown]
# ### Handling Missing Values

# %%
columns = list(mar_df.columns)

print('Missing values for each feature:\n')

for column in columns:
    null = mar_df[column].isnull().sum()
    print(column, ':',  null)
# Out:
# Missing values for each feature:
#
# ID : 0
# Year_Birth : 0
# Education : 0
# Marital_Status : 0
# Income : 24
# Kidhome : 0
# Teenhome : 0
# Dt_Customer : 0
# Recency : 0
# MntWines : 0
# MntFruits : 0
# MntMeatProducts : 0
# MntFishProducts : 0
# MntSweetProducts : 0
# MntGoldProds : 0
# NumDealsPurchases : 0
# NumWebPurchases : 0
# NumCatalogPurchases : 0
# NumStorePurchases : 0
# NumWebVisitsMonth : 0
# AcceptedCmp3 : 0
# AcceptedCmp4 : 0
# AcceptedCmp5 : 0
# AcceptedCmp1 : 0
# AcceptedCmp2 : 0
# Response : 0
# Complain : 0
# Country : 0

# %% [markdown]
# * 'Income' feature has 24 missing values
# * All other features have no missing values

# %% [markdown]
# Plotting the distribution of 'Income'

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=mar_df['Income'], kde=True)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %% [markdown]
# * Observation: Majority of the incomes are distributed between $0-$100000 Dollars with few outliers.
# * We can impute the missing values with the median to avoid the effect of outliers

# %%
mar_df['Income'] = mar_df['Income'].fillna(mar_df['Income'].median())

# %%
# checking for null values
mar_df['Income'].isnull().sum()
# Out:
# 0

# %%
mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0  2014-06-16        0       189        104              379
# 1            0  2014-06-15        0       464          5               64
# 2            1  2014-05-13        0       134         11               59
# 3            1  2014-05-11        0        10          0                1
# 4            0  2014-04-08        0         6         16               24
# ...        ...         ...      ...       ...        ...              ...
# 2235         1  2013-03-07       99       372         18              126
# 2236         0  2013-01-22       99         5         10               13
# 2237         0  2012-12-03       99       185          2               88
# 2238         0  2012-11-29       99       267         38              701
# 2239         2  2012-09-01       99       169         24              553
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 111               189           218                  1
# 1                   7                 0            37                  1
# 2                  15                 2            30                  1
# 3                   0                 0             0                  1
# 4                  11                 0            34                  2
# ...               ...               ...           ...                ...
# 2235               47                48            78                  2
# 2236                3                 8            16                  1
# 2237               15                 5            14                  2
# 2238              149               165            63                  1
# 2239              188                 0           144                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain Country
# 0                0             0         1         0      SP
# 1                0             1         1         0      CA
# 2                0             0         0         0      US
# 3                0             0         0         0     AUS
# 4                0             0         1         0      SP
# ...            ...           ...       ...       ...     ...
# 2235             0             0         0         0      US
# 2236             0             0         0         0      SP
# 2237             0             0         0         0      SP
# 2238             0             0         0         0     IND
# 2239             0             0         1         0      CA
#
# [2240 rows x 28 columns]

# %%
mar_df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering
#
# We can engineer new features from the available features in the raw data. This would help us in better understanding of the raw data and for better analysis.

# %% [markdown]
# * The total number of children can be engineered from the features 'Kidhome' and 'Teenhome'
#                     'Kidhome' + 'Teenhome' = 'Children'
#
# * The year the person became a customer can be engineered from 'Dt_Customer'
#
# * The total amount spent by each customer can be engineered from sum of all the amounts spent on individual products/items
#                     'MntWines' + 'MntFruits' + 'MntMeatProducts' + 'MntFishProducts' + 'MntSweetProducts' + 'MntGoldProds' = 'TotalMntSpent'
#
# * Total number of deals purchased can be obtained from sum of all the purchases made
#                     'NumDealsPurchases' + 'NumWebPurchases' + 'NumCatalogPurchases' + 'NumStorePurchases' = 'Total Purchases'
#
# * Total number of campaigns accepted by a customer can be obtained from the sum of campaigns accepted
#                     'AcceptedCmp3' + 'AcceptedCmp4' + 'AcceptedCmp5' + 'AcceptedCmp1' + 'AcceptedCmp2' + 'Response' = 'TotalCmpAccepted'

# %%
mar_df['Children'] = mar_df['Kidhome'] + mar_df['Teenhome']

# %%
mar_df[['Children']]
# Out:
#       Children
# 0            0
# 1            0
# 2            1
# 3            2
# 4            1
# ...        ...
# 2235         1
# 2236         1
# 2237         1
# 2238         0
# 2239         2
#
# [2240 rows x 1 columns]

# %%
mar_df['Year_Customer'] = pd.DatetimeIndex(mar_df['Dt_Customer']).year

# %%
mar_df[['Year_Customer']]
# Out:
#       Year_Customer
# 0              2014
# 1              2014
# 2              2014
# 3              2014
# 4              2014
# ...             ...
# 2235           2013
# 2236           2013
# 2237           2012
# 2238           2012
# 2239           2012
#
# [2240 rows x 1 columns]

# %%
mar_df['TotalMntSpent'] = mar_df['MntWines'] + mar_df['MntFruits'] + mar_df['MntMeatProducts'] + mar_df['MntFishProducts'] + mar_df['MntSweetProducts'] + mar_df['MntGoldProds']

# %%
mar_df[['TotalMntSpent']]
# Out:
#       TotalMntSpent
# 0              1190
# 1               577
# 2               251
# 3                11
# 4                91
# ...             ...
# 2235            689
# 2236             55
# 2237            309
# 2238           1383
# 2239           1078
#
# [2240 rows x 1 columns]

# %%
mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0  2014-06-16        0       189        104              379
# 1            0  2014-06-15        0       464          5               64
# 2            1  2014-05-13        0       134         11               59
# 3            1  2014-05-11        0        10          0                1
# 4            0  2014-04-08        0         6         16               24
# ...        ...         ...      ...       ...        ...              ...
# 2235         1  2013-03-07       99       372         18              126
# 2236         0  2013-01-22       99         5         10               13
# 2237         0  2012-12-03       99       185          2               88
# 2238         0  2012-11-29       99       267         38              701
# 2239         2  2012-09-01       99       169         24              553
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 111               189           218                  1
# 1                   7                 0            37                  1
# 2                  15                 2            30                  1
# 3                   0                 0             0                  1
# 4                  11                 0            34                  2
# ...               ...               ...           ...                ...
# 2235               47                48            78                  2
# 2236                3                 8            16                  1
# 2237               15                 5            14                  2
# 2238              149               165            63                  1
# 2239              188                 0           144                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain Country  Children  \
# 0                0             0         1         0      SP         0
# 1                0             1         1         0      CA         0
# 2                0             0         0         0      US         1
# 3                0             0         0         0     AUS         2
# 4                0             0         1         0      SP         1
# ...            ...           ...       ...       ...     ...       ...
# 2235             0             0         0         0      US         1
# 2236             0             0         0         0      SP         1
# 2237             0             0         0         0      SP         1
# 2238             0             0         0         0     IND         0
# 2239             0             0         1         0      CA         2
#
#       Year_Customer  TotalMntSpent
# 0              2014           1190
# 1              2014            577
# 2              2014            251
# 3              2014             11
# 4              2014             91
# ...             ...            ...
# 2235           2013            689
# 2236           2013             55
# 2237           2012            309
# 2238           2012           1383
# 2239           2012           1078
#
# [2240 rows x 31 columns]

# %%
mar_df['TotalPurchases'] = mar_df['NumDealsPurchases'] + mar_df['NumWebPurchases'] + mar_df['NumCatalogPurchases'] + mar_df['NumStorePurchases']

# %%
mar_df[['TotalPurchases']]
# Out:
#       TotalPurchases
# 0                 15
# 1                 18
# 2                 11
# 3                  4
# 4                  8
# ...              ...
# 2235              20
# 2236               5
# 2237              14
# 2238              20
# 2239              18
#
# [2240 rows x 1 columns]

# %%
mar_df['TotalCmpAccepted'] = mar_df['AcceptedCmp3'] + mar_df['AcceptedCmp4'] + mar_df['AcceptedCmp5'] + mar_df['AcceptedCmp1'] + mar_df['AcceptedCmp2'] + mar_df['Response']

# %%
mar_df[['TotalCmpAccepted']]
# Out:
#       TotalCmpAccepted
# 0                    1
# 1                    2
# 2                    0
# 3                    0
# 4                    2
# ...                ...
# 2235                 0
# 2236                 0
# 2237                 0
# 2238                 0
# 2239                 3
#
# [2240 rows x 1 columns]

# %%
mar_df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0            0  2014-06-16        0       189        104              379
# 1            0  2014-06-15        0       464          5               64
# 2            1  2014-05-13        0       134         11               59
# 3            1  2014-05-11        0        10          0                1
# 4            0  2014-04-08        0         6         16               24
# ...        ...         ...      ...       ...        ...              ...
# 2235         1  2013-03-07       99       372         18              126
# 2236         0  2013-01-22       99         5         10               13
# 2237         0  2012-12-03       99       185          2               88
# 2238         0  2012-11-29       99       267         38              701
# 2239         2  2012-09-01       99       169         24              553
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0                 111               189           218                  1
# 1                   7                 0            37                  1
# 2                  15                 2            30                  1
# 3                   0                 0             0                  1
# 4                  11                 0            34                  2
# ...               ...               ...           ...                ...
# 2235               47                48            78                  2
# 2236                3                 8            16                  1
# 2237               15                 5            14                  2
# 2238              149               165            63                  1
# 2239              188                 0           144                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     1             0             0             0
# 1                     5             0             0             0
# 2                     2             0             0             0
# 3                     7             0             0             0
# 4                     7             1             0             0
# ...                 ...           ...           ...           ...
# 2235                  4             0             0             0
# 2236                  8             0             0             0
# 2237                  8             0             0             0
# 2238                  3             0             0             0
# 2239                  7             0             1             1
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain Country  Children  \
# 0                0             0         1         0      SP         0
# 1                0             1         1         0      CA         0
# 2                0             0         0         0      US         1
# 3                0             0         0         0     AUS         2
# 4                0             0         1         0      SP         1
# ...            ...           ...       ...       ...     ...       ...
# 2235             0             0         0         0      US         1
# 2236             0             0         0         0      SP         1
# 2237             0             0         0         0      SP         1
# 2238             0             0         0         0     IND         0
# 2239             0             0         1         0      CA         2
#
#       Year_Customer  TotalMntSpent  TotalPurchases  TotalCmpAccepted
# 0              2014           1190              15                 1
# 1              2014            577              18                 2
# 2              2014            251              11                 0
# 3              2014             11               4                 0
# 4              2014             91               8                 2
# ...             ...            ...             ...               ...
# 2235           2013            689              20                 0
# 2236           2013             55               5                 0
# 2237           2012            309              14                 0
# 2238           2012           1383              20                 0
# 2239           2012           1078              18                 3
#
# [2240 rows x 33 columns]

# %%
mar_df.drop(columns=['ID', 'Kidhome', 'Teenhome', 'Dt_Customer'], inplace=True)

# %%
mar_df
# Out:
#       Year_Birth   Education Marital_Status   Income  Recency  MntWines  \
# 0           1970  Graduation       Divorced  84835.0        0       189
# 1           1961  Graduation         Single  57091.0        0       464
# 2           1958  Graduation        Married  67267.0        0       134
# 3           1967  Graduation       Together  32474.0        0        10
# 4           1989  Graduation         Single  21474.0        0         6
# ...          ...         ...            ...      ...      ...       ...
# 2235        1976         PhD       Divorced  66476.0       99       372
# 2236        1977    2n Cycle        Married  31056.0       99         5
# 2237        1976  Graduation       Divorced  46310.0       99       185
# 2238        1978  Graduation        Married  65819.0       99       267
# 2239        1969         PhD        Married  94871.0       99       169
#
#       MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0           104              379              111               189
# 1             5               64                7                 0
# 2            11               59               15                 2
# 3             0                1                0                 0
# 4            16               24               11                 0
# ...         ...              ...              ...               ...
# 2235         18              126               47                48
# 2236         10               13                3                 8
# 2237          2               88               15                 5
# 2238         38              701              149               165
# 2239         24              553              188                 0
#
#       MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0              218                  1                4                    4
# 1               37                  1                7                    3
# 2               30                  1                3                    2
# 3                0                  1                1                    0
# 4               34                  2                3                    1
# ...            ...                ...              ...                  ...
# 2235            78                  2                5                    2
# 2236            16                  1                1                    0
# 2237            14                  2                6                    1
# 2238            63                  1                5                    4
# 2239           144                  1                8                    5
#
#       NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 0                     6                  1             0             0
# 1                     7                  5             0             0
# 2                     5                  2             0             0
# 3                     2                  7             0             0
# 4                     2                  7             1             0
# ...                 ...                ...           ...           ...
# 2235                 11                  4             0             0
# 2236                  3                  8             0             0
# 2237                  5                  8             0             0
# 2238                 10                  3             0             0
# 2239                  4                  7             0             1
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain Country  \
# 0                0             0             0         1         0      SP
# 1                0             0             1         1         0      CA
# 2                0             0             0         0         0      US
# 3                0             0             0         0         0     AUS
# 4                0             0             0         1         0      SP
# ...            ...           ...           ...       ...       ...     ...
# 2235             0             0             0         0         0      US
# 2236             0             0             0         0         0      SP
# 2237             0             0             0         0         0      SP
# 2238             0             0             0         0         0     IND
# 2239             1             0             0         1         0      CA
#
#       Children  Year_Customer  TotalMntSpent  TotalPurchases  TotalCmpAccepted
# 0            0           2014           1190              15                 1
# 1            0           2014            577              18                 2
# 2            1           2014            251              11                 0
# 3            2           2014             11               4                 0
# 4            1           2014             91               8                 2
# ...        ...            ...            ...             ...               ...
# 2235         1           2013            689              20                 0
# 2236         1           2013             55               5                 0
# 2237         1           2012            309              14                 0
# 2238         0           2012           1383              20                 0
# 2239         2           2012           1078              18                 3
#
# [2240 rows x 29 columns]

# %% [markdown]
# ### Detecting and Treating Outliers:

# %% [markdown]
# * Box-plot is the best visual plot to detect outliers in the data

# %%
df_to_plot = mar_df.drop(columns=['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain'])

# %%
df_to_plot.plot(subplots=True, layout=(7,3), kind='box', figsize=(14,14))
plt.show()

# %% [markdown]
# * Here, we will use the concept of percentiles to detect outliers accurately.
#
# * Note: We can also use IQR (Inter Quartile Range) to detect outliers
#
#       IQR = Q3-Q1 ; where Q1 = 25th percentile value, Q3 = 75th percentile value
#
#       Lower Threshold (LT) = Q1 - 1.5 * IQR; all values falling below LT are outliers
#       Upper Threshold (HT) = Q3 + 1.5 * IQR; all values falling above HT are outliers
#
# * Extreme outliers:
#       Lower Threshold (LT) = Q1 - 3 * IQR; all values falling below LT are extreme outliers
#       Upper Threshold (HT) = Q3 + 3 * IQR; all values falling above HT are extreme outliers

# %% [markdown]
# ### Detecting outliers using percentiles:

# %% [markdown]
# * We will also treat the outliers as per the requirement

# %%
for i in range(0, 100, 10):
    percentile = mar_df['Year_Birth'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 0 percentile value is 1893
# 10 percentile value is 1952
# 20 percentile value is 1957
# 30 percentile value is 1962
# 40 percentile value is 1966
# 50 percentile value is 1970
# 60 percentile value is 1973
# 70 percentile value is 1976
# 80 percentile value is 1979
# 90 percentile value is 1984
# 100 percentile value is  1996

# %%
for i in range(0, 10, 1):
    percentile = mar_df['Year_Birth'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 0 percentile value is 1893
# 1 percentile value is 1945
# 2 percentile value is 1947
# 3 percentile value is 1948
# 4 percentile value is 1949
# 5 percentile value is 1950
# 6 percentile value is 1950
# 7 percentile value is 1951
# 8 percentile value is 1951
# 9 percentile value is 1952
# 100 percentile value is  1996

# %%
for i in range(90, 100, 1):
    percentile = mar_df['Year_Birth'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 1984
# 91 percentile value is 1985
# 92 percentile value is 1986
# 93 percentile value is 1986
# 94 percentile value is 1987
# 95 percentile value is 1988
# 96 percentile value is 1989
# 97 percentile value is 1989
# 98 percentile value is 1990
# 99 percentile value is 1992
# 100 percentile value is  1996

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['Year_Birth'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
# >"1940"
# Out:
# 0.0 percentile value is 1893
# 0.1 percentile value is 1900
# 0.2 percentile value is 1941
# 0.30000000000000004 percentile value is 1943
# 0.4 percentile value is 1943
# 0.5 percentile value is 1943
# 0.6000000000000001 percentile value is 1944
# 0.7000000000000001 percentile value is 1944
# 0.8 percentile value is 1944
# 0.9 percentile value is 1945

# %%
sns.boxplot(mar_df['Year_Birth'])
# Out:
# <AxesSubplot:xlabel='Year_Birth'>

# %%
mar_df = mar_df[mar_df['Year_Birth'] > 1940].reset_index(drop=True)

# %%
sns.boxplot(mar_df['Year_Birth'])
# Out:
# <AxesSubplot:xlabel='Year_Birth'>

# %%
for i in range(0, 100, 10):
    percentile = mar_df['Income'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 0 percentile value is 1730.0
# 10 percentile value is 24206.0
# 20 percentile value is 32218.0
# 30 percentile value is 38361.0
# 40 percentile value is 44931.0
# 50 percentile value is 51381.5
# 60 percentile value is 58138.0
# 70 percentile value is 65106.0
# 80 percentile value is 71626.0
# 90 percentile value is 79800.0
# 100 percentile value is  666666.0

# %%
for i in range(90, 100, 1):
    percentile = mar_df['Income'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 79800.0
# 91 percentile value is 80398.0
# 92 percentile value is 81217.0
# 93 percentile value is 82072.0
# 94 percentile value is 82800.0
# 95 percentile value is 84117.0
# 96 percentile value is 85696.0
# 97 percentile value is 87679.0
# 98 percentile value is 90765.0
# 99 percentile value is 94472.0
# 100 percentile value is  666666.0

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['Income'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 94472.0
# 99.1 percentile value is 94871.0
# 99.2 percentile value is 96547.0
# 99.3 percentile value is 96876.0
# 99.4 percentile value is 98777.0
# 99.5 percentile value is 102160.0
# 99.6 percentile value is 113734.0
# 99.7 percentile value is 156924.0
# 99.8 percentile value is 157243.0
# 99.9 percentile value is 160803.0
# 100 percentile value is  666666.0

# %%
sns.boxplot(mar_df['Income'])
# Out:
# <AxesSubplot:xlabel='Income'>

# %%
mar_df = mar_df[mar_df['Income'] < 120000].reset_index(drop=True)

# %%
sns.boxplot(mar_df['Income'])
# Out:
# <AxesSubplot:xlabel='Income'>

# %%
for i in range(0, 100, 10):
    percentile = mar_df['MntWines'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 0 percentile value is 0
# 10 percentile value is 6
# 20 percentile value is 16
# 30 percentile value is 34
# 40 percentile value is 84
# 50 percentile value is 177
# 60 percentile value is 291
# 70 percentile value is 421
# 80 percentile value is 583
# 90 percentile value is 823
# 100 percentile value is  1493

# %%
for i in range(90, 100, 1):
    percentile = mar_df['MntWines'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 823
# 91 percentile value is 861
# 92 percentile value is 901
# 93 percentile value is 938
# 94 percentile value is 967
# 95 percentile value is 1000
# 96 percentile value is 1045
# 97 percentile value is 1111
# 98 percentile value is 1193
# 99 percentile value is 1285
# 100 percentile value is  1493

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['MntWines'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 1285
# 99.1 percentile value is 1296
# 99.2 percentile value is 1308
# 99.3 percentile value is 1315
# 99.4 percentile value is 1332
# 99.5 percentile value is 1379
# 99.6 percentile value is 1449
# 99.7 percentile value is 1462
# 99.8 percentile value is 1478
# 99.9 percentile value is 1492
# 100 percentile value is  1493

# %%
sns.boxplot(mar_df['MntWines'])
# Out:
# <AxesSubplot:xlabel='MntWines'>

# %% [markdown]
# * There are many datapoints which are low-level outliers. As these are real and important observations, we will keep them. We will only remove extreme outliers.

# %%
for i in range(0, 100, 10):
    percentile = mar_df['MntFruits'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 0 percentile value is 0
# 10 percentile value is 0
# 20 percentile value is 1
# 30 percentile value is 2
# 40 percentile value is 4
# 50 percentile value is 8
# 60 percentile value is 15
# 70 percentile value is 25
# 80 percentile value is 44
# 90 percentile value is 83
# 100 percentile value is  199

# %%
for i in range(90, 100, 1):
    percentile = mar_df['MntFruits'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 83
# 91 percentile value is 89
# 92 percentile value is 98
# 93 percentile value is 105
# 94 percentile value is 112
# 95 percentile value is 123
# 96 percentile value is 133
# 97 percentile value is 142
# 98 percentile value is 159
# 99 percentile value is 172
# 100 percentile value is  199

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['MntFruits'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 172
# 99.1 percentile value is 174
# 99.2 percentile value is 178
# 99.3 percentile value is 183
# 99.4 percentile value is 183
# 99.5 percentile value is 185
# 99.6 percentile value is 190
# 99.7 percentile value is 193
# 99.8 percentile value is 194
# 99.9 percentile value is 197
# 100 percentile value is  199

# %%
sns.boxplot(mar_df['MntFruits'])
# Out:
# <AxesSubplot:xlabel='MntFruits'>

# %% [markdown]
# * There are many datapoints which are low-level outliers. As these are real and important observations, we will keep them. We will only remove extreme outliers.

# %%
for i in range(90, 100, 1):
    percentile = mar_df['MntMeatProducts'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 497
# 91 percentile value is 520
# 92 percentile value is 549
# 93 percentile value is 573
# 94 percentile value is 614
# 95 percentile value is 685
# 96 percentile value is 724
# 97 percentile value is 774
# 98 percentile value is 818
# 99 percentile value is 899
# 100 percentile value is  1725

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['MntMeatProducts'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])

# >1000
# Out:
# 99.0 percentile value is 899
# 99.1 percentile value is 915
# 99.2 percentile value is 925
# 99.3 percentile value is 925
# 99.4 percentile value is 932
# 99.5 percentile value is 936
# 99.6 percentile value is 951
# 99.7 percentile value is 961
# 99.8 percentile value is 974
# 99.9 percentile value is 984
# 100 percentile value is  1725

# %%
sns.boxplot(mar_df['MntMeatProducts'])
# Out:
# <AxesSubplot:xlabel='MntMeatProducts'>

# %%
mar_df = mar_df[mar_df['MntMeatProducts'] < 1000].reset_index(drop=True)

# %%
sns.boxplot(mar_df['MntMeatProducts'])
# Out:
# <AxesSubplot:xlabel='MntMeatProducts'>

# %% [markdown]
# * We have removed extreme outliers and kept low-level outliers which are needed for analysis

# %%
mar_df['MntMeatProducts'].quantile(q=[0.25, 0.50, 0.75, 0.9, 0.95, 1.0])
# Out:
# 0.25     16.00
# 0.50     67.00
# 0.75    230.00
# 0.90    493.50
# 0.95    673.75
# 1.00    984.00
# Name: MntMeatProducts, dtype: float64

# %%
for i in range(90, 100, 1):
    percentile = mar_df['MntFishProducts'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 121
# 91 percentile value is 132
# 92 percentile value is 138
# 93 percentile value is 150
# 94 percentile value is 158
# 95 percentile value is 169
# 96 percentile value is 180
# 97 percentile value is 197
# 98 percentile value is 210
# 99 percentile value is 227
# 100 percentile value is  259

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['MntFishProducts'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 227
# 99.1 percentile value is 229
# 99.2 percentile value is 234
# 99.3 percentile value is 237
# 99.4 percentile value is 240
# 99.5 percentile value is 242
# 99.6 percentile value is 250
# 99.7 percentile value is 250
# 99.8 percentile value is 254
# 99.9 percentile value is 258
# 100 percentile value is  259

# %%
sns.boxplot(mar_df['MntFishProducts'])
# Out:
# <AxesSubplot:xlabel='MntFishProducts'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['MntSweetProducts'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 89
# 91 percentile value is 94
# 92 percentile value is 101
# 93 percentile value is 107
# 94 percentile value is 118
# 95 percentile value is 126
# 96 percentile value is 137
# 97 percentile value is 148
# 98 percentile value is 161
# 99 percentile value is 178
# 100 percentile value is  263

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['MntSweetProducts'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 178
# 99.1 percentile value is 179
# 99.2 percentile value is 185
# 99.3 percentile value is 188
# 99.4 percentile value is 189
# 99.5 percentile value is 192
# 99.6 percentile value is 194
# 99.7 percentile value is 194
# 99.8 percentile value is 196
# 99.9 percentile value is 198
# 100 percentile value is  263

# %%
sns.boxplot(mar_df['MntSweetProducts'])
# Out:
# <AxesSubplot:xlabel='MntSweetProducts'>

# %%
mar_df = mar_df[mar_df['MntSweetProducts'] < 200].reset_index(drop=True)

# %%
sns.boxplot(mar_df['MntSweetProducts'])
# Out:
# <AxesSubplot:xlabel='MntSweetProducts'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['MntGoldProds'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 122
# 91 percentile value is 129
# 92 percentile value is 135
# 93 percentile value is 145
# 94 percentile value is 152
# 95 percentile value is 163
# 96 percentile value is 174
# 97 percentile value is 187
# 98 percentile value is 200
# 99 percentile value is 227
# 100 percentile value is  321

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['MntGoldProds'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 227
# 99.1 percentile value is 229
# 99.2 percentile value is 232
# 99.3 percentile value is 241
# 99.4 percentile value is 241
# 99.5 percentile value is 241
# 99.6 percentile value is 242
# 99.7 percentile value is 246
# 99.8 percentile value is 248
# 99.9 percentile value is 262
# 100 percentile value is  321

# %%
sns.boxplot(mar_df['MntGoldProds'])
# Out:
# <AxesSubplot:xlabel='MntGoldProds'>

# %%
mar_df = mar_df[mar_df['MntGoldProds'] < 250].reset_index(drop=True)

# %%
sns.boxplot(mar_df['MntGoldProds'])
# Out:
# <AxesSubplot:xlabel='MntGoldProds'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['NumWebPurchases'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 8
# 91 percentile value is 8
# 92 percentile value is 8
# 93 percentile value is 9
# 94 percentile value is 9
# 95 percentile value is 9
# 96 percentile value is 9
# 97 percentile value is 10
# 98 percentile value is 10
# 99 percentile value is 11
# 100 percentile value is  11

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['NumWebPurchases'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 11
# 99.1 percentile value is 11
# 99.2 percentile value is 11
# 99.3 percentile value is 11
# 99.4 percentile value is 11
# 99.5 percentile value is 11
# 99.6 percentile value is 11
# 99.7 percentile value is 11
# 99.8 percentile value is 11
# 99.9 percentile value is 11
# 100 percentile value is  11

# %%
sns.boxplot(mar_df['NumWebPurchases'])
# Out:
# <AxesSubplot:xlabel='NumWebPurchases'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['NumCatalogPurchases'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 7
# 91 percentile value is 7
# 92 percentile value is 7
# 93 percentile value is 8
# 94 percentile value is 8
# 95 percentile value is 8
# 96 percentile value is 9
# 97 percentile value is 10
# 98 percentile value is 10
# 99 percentile value is 10
# 100 percentile value is  11

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['NumCatalogPurchases'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 10
# 99.1 percentile value is 10
# 99.2 percentile value is 11
# 99.3 percentile value is 11
# 99.4 percentile value is 11
# 99.5 percentile value is 11
# 99.6 percentile value is 11
# 99.7 percentile value is 11
# 99.8 percentile value is 11
# 99.9 percentile value is 11
# 100 percentile value is  11

# %%
sns.boxplot(mar_df['NumCatalogPurchases'])
# Out:
# <AxesSubplot:xlabel='NumCatalogPurchases'>

# %%
mar_df = mar_df[mar_df['NumCatalogPurchases'] < 10].reset_index(drop=True)

# %%
sns.boxplot(mar_df['NumCatalogPurchases'])
# Out:
# <AxesSubplot:xlabel='NumCatalogPurchases'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['NumStorePurchases'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 11
# 91 percentile value is 11
# 92 percentile value is 12
# 93 percentile value is 12
# 94 percentile value is 12
# 95 percentile value is 12
# 96 percentile value is 12
# 97 percentile value is 13
# 98 percentile value is 13
# 99 percentile value is 13
# 100 percentile value is  13

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['NumStorePurchases'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 13
# 99.1 percentile value is 13
# 99.2 percentile value is 13
# 99.3 percentile value is 13
# 99.4 percentile value is 13
# 99.5 percentile value is 13
# 99.6 percentile value is 13
# 99.7 percentile value is 13
# 99.8 percentile value is 13
# 99.9 percentile value is 13
# 100 percentile value is  13

# %%
sns.boxplot(mar_df['NumStorePurchases'])
# Out:
# <AxesSubplot:xlabel='NumStorePurchases'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['NumWebVisitsMonth'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 8
# 91 percentile value is 8
# 92 percentile value is 8
# 93 percentile value is 8
# 94 percentile value is 8
# 95 percentile value is 8
# 96 percentile value is 9
# 97 percentile value is 9
# 98 percentile value is 9
# 99 percentile value is 9
# 100 percentile value is  20

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['NumWebVisitsMonth'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 9
# 99.1 percentile value is 9
# 99.2 percentile value is 9
# 99.3 percentile value is 9
# 99.4 percentile value is 9
# 99.5 percentile value is 10
# 99.6 percentile value is 10
# 99.7 percentile value is 14
# 99.8 percentile value is 19
# 99.9 percentile value is 20
# 100 percentile value is  20

# %%
sns.boxplot(mar_df['NumWebVisitsMonth'])
# Out:
# <AxesSubplot:xlabel='NumWebVisitsMonth'>

# %%
mar_df = mar_df[mar_df['NumWebVisitsMonth'] < 13].reset_index(drop=True)

# %%
sns.boxplot(mar_df['NumWebVisitsMonth'])
# Out:
# <AxesSubplot:xlabel='NumWebVisitsMonth'>

# %%
mar_df.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country',
#        'Children', 'Year_Customer', 'TotalMntSpent', 'TotalPurchases',
#        'TotalCmpAccepted'],
#       dtype='object')

# %%
for i in range(90, 100, 1):
    percentile = mar_df['Children'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 2
# 91 percentile value is 2
# 92 percentile value is 2
# 93 percentile value is 2
# 94 percentile value is 2
# 95 percentile value is 2
# 96 percentile value is 2
# 97 percentile value is 2
# 98 percentile value is 3
# 99 percentile value is 3
# 100 percentile value is  3

# %%
sns.boxplot(mar_df['Children'])
# Out:
# <AxesSubplot:xlabel='Children'>

# %%
mar_df = mar_df[mar_df['Children'] < 3].reset_index(drop=True)

# %%
sns.boxplot(mar_df['Children'])
# Out:
# <AxesSubplot:xlabel='Children'>

# %%
sns.boxplot(mar_df['TotalMntSpent'])
# Out:
# <AxesSubplot:xlabel='TotalMntSpent'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['TotalMntSpent'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 1501
# 91 percentile value is 1555
# 92 percentile value is 1597
# 93 percentile value is 1650
# 94 percentile value is 1690
# 95 percentile value is 1753
# 96 percentile value is 1820
# 97 percentile value is 1918
# 98 percentile value is 2008
# 99 percentile value is 2116
# 100 percentile value is  2525

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['TotalMntSpent'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 2116
# 99.1 percentile value is 2153
# 99.2 percentile value is 2194
# 99.3 percentile value is 2211
# 99.4 percentile value is 2231
# 99.5 percentile value is 2279
# 99.6 percentile value is 2302
# 99.7 percentile value is 2346
# 99.8 percentile value is 2352
# 99.9 percentile value is 2486
# 100 percentile value is  2525

# %%
mar_df = mar_df[mar_df['TotalMntSpent'] < 2300].reset_index(drop=True)

# %%
sns.boxplot(mar_df['TotalMntSpent'])
# Out:
# <AxesSubplot:xlabel='TotalMntSpent'>

# %%
sns.boxplot(mar_df['TotalPurchases'])
# Out:
# <AxesSubplot:xlabel='TotalPurchases'>

# %%
sns.boxplot(mar_df['TotalCmpAccepted'])
# Out:
# <AxesSubplot:xlabel='TotalCmpAccepted'>

# %%
for i in range(90, 100, 1):
    percentile = mar_df['TotalCmpAccepted'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(i,percentile[int(len(percentile)*(float(i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 90 percentile value is 1
# 91 percentile value is 2
# 92 percentile value is 2
# 93 percentile value is 2
# 94 percentile value is 2
# 95 percentile value is 2
# 96 percentile value is 2
# 97 percentile value is 3
# 98 percentile value is 3
# 99 percentile value is 4
# 100 percentile value is  5

# %%
for i in np.arange(0.0, 1.0, 0.1):
    percentile = mar_df['TotalCmpAccepted'].values
    percentile = np.sort(percentile, axis=None)
    print("{} percentile value is {}".format(99+i,percentile[int(len(percentile)*(float(99+i)/100))]))
print ("100 percentile value is ",percentile[-1])
# Out:
# 99.0 percentile value is 4
# 99.1 percentile value is 4
# 99.2 percentile value is 4
# 99.3 percentile value is 4
# 99.4 percentile value is 4
# 99.5 percentile value is 4
# 99.6 percentile value is 4
# 99.7 percentile value is 5
# 99.8 percentile value is 5
# 99.9 percentile value is 5
# 100 percentile value is  5

# %%
mar_df[mar_df['TotalCmpAccepted'] == 3].count().unique()
# Out:
# array([44], dtype=int64)

# %%
mar_df[mar_df['TotalCmpAccepted'] == 4].count().unique()
# Out:
# array([25], dtype=int64)

# %%
mar_df[mar_df['TotalCmpAccepted'] == 5].count().unique()
# Out:
# array([8], dtype=int64)

# %% [markdown]
# * We will keep all of them all since there is not much difference between values' 3 and 5

# %% [markdown]
# ## Uni-Variate Analysis

# %% [markdown]
# * Let us understand the distributions of each feature

# %%
mar_df.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country',
#        'Children', 'Year_Customer', 'TotalMntSpent', 'TotalPurchases',
#        'TotalCmpAccepted'],
#       dtype='object')

# %% [markdown]
# ### Histogram and Probability Density Function (PDF)

# %%
df_to_plot = mar_df.drop(columns=['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain'])

# %%
for column in df_to_plot:
    sns.histplot(data=mar_df[column], kde=True)
    plt.xlabel(column)
    plt.show()

# %% [markdown]
# ##### Important Observations:
#
# * Education: Majority of customers' have a Graduate degree - 1052
# * Income: Income is distributed between \$(0-100000)
# * MntWines: Right-Skewed distribution. Around 800 customers spent between \$(0-70)
# * MntFruits: Right-Skewed distribution. Around 1100 customers spent between \$(0-10)
# * MntMeatProducts: Right-Skewed distribution. Around 1200 customers spent between \$(0-100)
# * MntFishProducts: Right-Skewed distribution. Around 1100 customers spent between \$(0-15)
# * MntSweetProducts: Right-Skewed distribution. Around 1100 customers spent between \$(0-10)
# * MntGoldProds: Right-Skewed distribution. Around 1000 customers spent between \$(0-25)
#
#     MntWines, MntFruits, MntMeatProduct, MntFishProducts, MntSweetProducts, MntGoldProds follow a Log-normal distribution. That implies, there are large number of customers who have spent less-medium amount, and few number of customers who have spent high amount on these products. As the standard deviation is increasing, the tail of the distribution is also increasing.
#
#
# * 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases' are all Right-Skewed distributions'.
# * 'NumWebVisitsMonth' is Left-Skewed distribution
# * Country: Majority of customers' are from SP (Spain) with 1032 customers'
# * Children: About 1100 customers' have 1 children
# * TotalMntSpent: Right-Skewed distribution. Around 1000 customers' spent between \$(0-320)
# * TotalCmpAccepted: Right-Skewed distribution. Around 1500 customers' did not accept any campaign

# %%
mar_df[mar_df['Education'] == 'Graduation'].count().unique()
# Out:
# array([1052], dtype=int64)

# %%
mar_df[mar_df['MntWines'] < 70].count().unique()
# Out:
# array([1107], dtype=int64)

# %%
mar_df[mar_df['MntFruits'] < 10].count().unique()
# Out:
# array([1107], dtype=int64)

# %%
mar_df[mar_df['MntMeatProducts'] < 100].count().unique()
# Out:
# array([1221], dtype=int64)

# %%
mar_df[mar_df['MntFishProducts'] < 15].count().unique()
# Out:
# array([1114], dtype=int64)

# %%
mar_df[mar_df['MntSweetProducts'] < 10].count().unique()
# Out:
# array([1098], dtype=int64)

# %%
mar_df[mar_df['MntGoldProds'] < 25].count().unique()
# Out:
# array([1055], dtype=int64)

# %%
mar_df[mar_df['Country'] == 'SP'].count().unique()
# Out:
# array([1032], dtype=int64)

# %%
mar_df[mar_df['Children'] == 1].count().unique()
# Out:
# array([1100], dtype=int64)

# %%
mar_df[mar_df['TotalMntSpent'] < 320].count().unique()
# Out:
# array([1003], dtype=int64)

# %%
mar_df[mar_df['TotalCmpAccepted'] == 0].count().unique()
# Out:
# array([1532], dtype=int64)

# %% [markdown]
# ### 1-D Scatter Plot

# %%
for column in df_to_plot:
    plt.scatter(x = mar_df[column], y = np.random.rand(len(mar_df)), c='orange')
    plt.xlabel(column)
    plt.show()

# %% [markdown]
# ##### Important Observations:
#
# * Year_Birth: fall bewteen 1940-1995
# * Income: Between \$(0-100000)
# * TotalPurchases: 0-32
#
#
# * Amount spent on each product category:
#     * MntWines: \$(0-1450)
#     * MntFruits: \$(0-200)
#
#     * MntMeatProducts: \$(0-1000)
#     * MntFishProducts: \$(0-250)
#     * MntSweetProducts: \$(0-200)
#     * MntGoldProds: : \$(0-250)
#
#
# * TotalMntSpent: \$(0-2300)

# %%
mar_df
# Out:
#       Year_Birth   Education Marital_Status   Income  Recency  MntWines  \
# 0           1970  Graduation       Divorced  84835.0        0       189
# 1           1961  Graduation         Single  57091.0        0       464
# 2           1958  Graduation        Married  67267.0        0       134
# 3           1967  Graduation       Together  32474.0        0        10
# 4           1989  Graduation         Single  21474.0        0         6
# ...          ...         ...            ...      ...      ...       ...
# 2079        1976         PhD       Divorced  66476.0       99       372
# 2080        1977    2n Cycle        Married  31056.0       99         5
# 2081        1976  Graduation       Divorced  46310.0       99       185
# 2082        1978  Graduation        Married  65819.0       99       267
# 2083        1969         PhD        Married  94871.0       99       169
#
#       MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0           104              379              111               189
# 1             5               64                7                 0
# 2            11               59               15                 2
# 3             0                1                0                 0
# 4            16               24               11                 0
# ...         ...              ...              ...               ...
# 2079         18              126               47                48
# 2080         10               13                3                 8
# 2081          2               88               15                 5
# 2082         38              701              149               165
# 2083         24              553              188                 0
#
#       MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0              218                  1                4                    4
# 1               37                  1                7                    3
# 2               30                  1                3                    2
# 3                0                  1                1                    0
# 4               34                  2                3                    1
# ...            ...                ...              ...                  ...
# 2079            78                  2                5                    2
# 2080            16                  1                1                    0
# 2081            14                  2                6                    1
# 2082            63                  1                5                    4
# 2083           144                  1                8                    5
#
#       NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 0                     6                  1             0             0
# 1                     7                  5             0             0
# 2                     5                  2             0             0
# 3                     2                  7             0             0
# 4                     2                  7             1             0
# ...                 ...                ...           ...           ...
# 2079                 11                  4             0             0
# 2080                  3                  8             0             0
# 2081                  5                  8             0             0
# 2082                 10                  3             0             0
# 2083                  4                  7             0             1
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain Country  \
# 0                0             0             0         1         0      SP
# 1                0             0             1         1         0      CA
# 2                0             0             0         0         0      US
# 3                0             0             0         0         0     AUS
# 4                0             0             0         1         0      SP
# ...            ...           ...           ...       ...       ...     ...
# 2079             0             0             0         0         0      US
# 2080             0             0             0         0         0      SP
# 2081             0             0             0         0         0      SP
# 2082             0             0             0         0         0     IND
# 2083             1             0             0         1         0      CA
#
#       Children  Year_Customer  TotalMntSpent  TotalPurchases  TotalCmpAccepted
# 0            0           2014           1190              15                 1
# 1            0           2014            577              18                 2
# 2            1           2014            251              11                 0
# 3            2           2014             11               4                 0
# 4            1           2014             91               8                 2
# ...        ...            ...            ...             ...               ...
# 2079         1           2013            689              20                 0
# 2080         1           2013             55               5                 0
# 2081         1           2012            309              14                 0
# 2082         0           2012           1383              20                 0
# 2083         2           2012           1078              18                 3
#
# [2084 rows x 29 columns]

# %% [markdown]
# ### As the features are close to 30, we would first find the correlations between different features and then plot the necessary 2-D Plots

# %% [markdown]
# ### Correlation:

# %% [markdown]
# #### Now, let us find out the correlation between various features. Are they positively correlated, negatively correlated , or not related at all.

# %% [markdown]
# * We will use the Spearman Rank Correlation Coefficient (r) since it will perform well for both linearly and non-linearly related features, unlike Pearson Correlation Coefficient which will perform well only for linearly related features.

# %%
correlation = mar_df.corr(method='spearman')
correlation
# Out:
#                      Year_Birth    Income   Recency  MntWines  MntFruits  \
# Year_Birth             1.000000 -0.231760 -0.007208 -0.247716  -0.037959
# Income                -0.231760  1.000000  0.001514  0.847712   0.576913
# Recency               -0.007208  0.001514  1.000000  0.006737   0.024096
# MntWines              -0.247716  0.847712  0.006737  1.000000   0.498293
# MntFruits             -0.037959  0.576913  0.024096  0.498293   1.000000
# MntMeatProducts       -0.132647  0.824959  0.017044  0.829724   0.707947
# MntFishProducts       -0.036148  0.572464  0.006392  0.504895   0.697164
# MntSweetProducts      -0.008360  0.569434  0.034305  0.500359   0.688370
# MntGoldProds          -0.090882  0.513370  0.010788  0.567399   0.553538
# NumDealsPurchases     -0.099664 -0.174049 -0.003475  0.070374  -0.101742
# NumWebPurchases       -0.169804  0.595293 -0.002828  0.750219   0.472663
# NumCatalogPurchases   -0.194610  0.795180  0.020061  0.829019   0.622372
# NumStorePurchases     -0.194327  0.754859  0.002457  0.815974   0.576892
# NumWebVisitsMonth      0.147553 -0.630379 -0.022532 -0.394308  -0.440954
# AcceptedCmp3           0.071813 -0.043070 -0.032886  0.002560  -0.012970
# AcceptedCmp4          -0.061240  0.222132  0.016167  0.312571   0.022230
# AcceptedCmp5           0.021934  0.374450  0.000413  0.347733   0.215475
# AcceptedCmp1           0.003388  0.311045 -0.015769  0.285978   0.155890
# AcceptedCmp2          -0.010052  0.104040 -0.004458  0.135762  -0.003573
# Response               0.031438  0.122575 -0.211524  0.160047   0.113533
# Complain              -0.008636 -0.032893  0.000711 -0.036307  -0.008453
# Children              -0.082244 -0.352934  0.004379 -0.322066  -0.451674
# Year_Customer         -0.020947  0.017776 -0.012985 -0.137692  -0.115543
# TotalMntSpent         -0.176301  0.860949  0.010347  0.934235   0.674368
# TotalPurchases        -0.204805  0.725022  0.006070  0.859624   0.569089
# TotalCmpAccepted      -0.009304  0.282750 -0.107679  0.355258   0.142075
#
#                      MntMeatProducts  MntFishProducts  MntSweetProducts  \
# Year_Birth                 -0.132647        -0.036148         -0.008360
# Income                      0.824959         0.572464          0.569434
# Recency                     0.017044         0.006392          0.034305
# MntWines                    0.829724         0.504895          0.500359
# MntFruits                   0.707947         0.697164          0.688370
# MntMeatProducts             1.000000         0.722368          0.703149
# MntFishProducts             0.722368         1.000000          0.698834
# MntSweetProducts            0.703149         0.698834          1.000000
# MntGoldProds                0.639455         0.555203          0.535781
# NumDealsPurchases          -0.020146        -0.114430         -0.096752
# NumWebPurchases             0.705136         0.464446          0.459480
# NumCatalogPurchases         0.846731         0.647671          0.631798
# NumStorePurchases           0.796894         0.576993          0.581154
# NumWebVisitsMonth          -0.483677        -0.457842         -0.451206
# AcceptedCmp3               -0.020563        -0.049230         -0.042097
# AcceptedCmp4                0.136731        -0.008707         -0.004764
# AcceptedCmp5                0.312742         0.201667          0.245956
# AcceptedCmp1                0.273239         0.196209          0.207834
# AcceptedCmp2                0.062902        -0.006243         -0.009942
# Response                    0.192039         0.080262          0.101321
# Complain                   -0.024761        -0.032261         -0.038727
# Children                   -0.474348        -0.483417         -0.449852
# Year_Customer              -0.145846        -0.118410         -0.112437
# TotalMntSpent               0.938923         0.688086          0.672558
# TotalPurchases              0.823438         0.577714          0.575210
# TotalCmpAccepted            0.284925         0.119554          0.138497
#
#                      MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# Year_Birth              -0.090882          -0.099664        -0.169804
# Income                   0.513370          -0.174049         0.595293
# Recency                  0.010788          -0.003475        -0.002828
# MntWines                 0.567399           0.070374         0.750219
# MntFruits                0.553538          -0.101742         0.472663
# MntMeatProducts          0.639455          -0.020146         0.705136
# MntFishProducts          0.555203          -0.114430         0.464446
# MntSweetProducts         0.535781          -0.096752         0.459480
# MntGoldProds             1.000000           0.116685         0.581064
# NumDealsPurchases        0.116685           1.000000         0.305521
# NumWebPurchases          0.581064           0.305521         1.000000
# NumCatalogPurchases      0.651777          -0.030458         0.636043
# NumStorePurchases        0.536186           0.104588         0.680982
# NumWebVisitsMonth       -0.246061           0.387101        -0.095581
# AcceptedCmp3             0.124232          -0.000164         0.002840
# AcceptedCmp4             0.064140           0.008547         0.182148
# AcceptedCmp5             0.172883          -0.238794         0.167562
# AcceptedCmp1             0.157789          -0.162115         0.172820
# AcceptedCmp2             0.071867          -0.050657         0.034274
# Response                 0.161506          -0.013657         0.146713
# Complain                -0.040545           0.026147        -0.022387
# Children                -0.299624           0.545993        -0.177953
# Year_Customer           -0.201158          -0.189397        -0.181682
# TotalMntSpent            0.694881           0.004234         0.747669
# TotalPurchases           0.637588           0.304948         0.864374
# TotalCmpAccepted         0.236248          -0.074654         0.232858
#
#                      NumCatalogPurchases  NumStorePurchases  \
# Year_Birth                     -0.194610          -0.194327
# Income                          0.795180           0.754859
# Recency                         0.020061           0.002457
# MntWines                        0.829019           0.815974
# MntFruits                       0.622372           0.576892
# MntMeatProducts                 0.846731           0.796894
# MntFishProducts                 0.647671           0.576993
# MntSweetProducts                0.631798           0.581154
# MntGoldProds                    0.651777           0.536186
# NumDealsPurchases              -0.030458           0.104588
# NumWebPurchases                 0.636043           0.680982
# NumCatalogPurchases             1.000000           0.722564
# NumStorePurchases               0.722564           1.000000
# NumWebVisitsMonth              -0.533627          -0.473962
# AcceptedCmp3                    0.071936          -0.117060
# AcceptedCmp4                    0.191858           0.208286
# AcceptedCmp5                    0.307943           0.225368
# AcceptedCmp1                    0.283503           0.200351
# AcceptedCmp2                    0.106414           0.091045
# Response                        0.190730           0.022529
# Complain                       -0.031518          -0.026033
# Children                       -0.441382          -0.336027
# Year_Customer                  -0.123595          -0.102139
# TotalMntSpent                   0.892392           0.827730
# TotalPurchases                  0.824873           0.894347
# TotalCmpAccepted                0.341054           0.151239
#
#                      NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# Year_Birth                    0.147553      0.071813     -0.061240
# Income                       -0.630379     -0.043070      0.222132
# Recency                      -0.022532     -0.032886      0.016167
# MntWines                     -0.394308      0.002560      0.312571
# MntFruits                    -0.440954     -0.012970      0.022230
# MntMeatProducts              -0.483677     -0.020563      0.136731
# MntFishProducts              -0.457842     -0.049230     -0.008707
# MntSweetProducts             -0.451206     -0.042097     -0.004764
# MntGoldProds                 -0.246061      0.124232      0.064140
# NumDealsPurchases             0.387101     -0.000164      0.008547
# NumWebPurchases              -0.095581      0.002840      0.182148
# NumCatalogPurchases          -0.533627      0.071936      0.191858
# NumStorePurchases            -0.473962     -0.117060      0.208286
# NumWebVisitsMonth             1.000000      0.072617     -0.024125
# AcceptedCmp3                  0.072617      1.000000     -0.076672
# AcceptedCmp4                 -0.024125     -0.076672      1.000000
# AcceptedCmp5                 -0.264789      0.051244      0.296697
# AcceptedCmp1                 -0.186388      0.064905      0.232381
# AcceptedCmp2                 -0.010788      0.083729      0.285674
# Response                      0.037952      0.228069      0.164797
# Complain                      0.022191     -0.004823     -0.026367
# Children                      0.417676      0.010082     -0.090789
# Year_Customer                -0.278130      0.006960     -0.009778
# TotalMntSpent                -0.465111      0.009087      0.244343
# TotalPurchases               -0.309689     -0.018628      0.208696
# TotalCmpAccepted             -0.056128      0.465528      0.500692
#
#                      AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  \
# Year_Birth               0.021934      0.003388     -0.010052  0.031438
# Income                   0.374450      0.311045      0.104040  0.122575
# Recency                  0.000413     -0.015769     -0.004458 -0.211524
# MntWines                 0.347733      0.285978      0.135762  0.160047
# MntFruits                0.215475      0.155890     -0.003573  0.113533
# MntMeatProducts          0.312742      0.273239      0.062902  0.192039
# MntFishProducts          0.201667      0.196209     -0.006243  0.080262
# MntSweetProducts         0.245956      0.207834     -0.009942  0.101321
# MntGoldProds             0.172883      0.157789      0.071867  0.161506
# NumDealsPurchases       -0.238794     -0.162115     -0.050657 -0.013657
# NumWebPurchases          0.167562      0.172820      0.034274  0.146713
# NumCatalogPurchases      0.307943      0.283503      0.106414  0.190730
# NumStorePurchases        0.225368      0.200351      0.091045  0.022529
# NumWebVisitsMonth       -0.264789     -0.186388     -0.010788  0.037952
# AcceptedCmp3             0.051244      0.064905      0.083729  0.228069
# AcceptedCmp4             0.296697      0.232381      0.285674  0.164797
# AcceptedCmp5             1.000000      0.372391      0.222290  0.294769
# AcceptedCmp1             0.372391      1.000000      0.169776  0.246646
# AcceptedCmp2             0.222290      0.169776      1.000000  0.168221
# Response                 0.294769      0.246646      0.168221  1.000000
# Complain                -0.024663     -0.022868     -0.010893 -0.008035
# Children                -0.293254     -0.239638     -0.080939 -0.144124
# Year_Customer            0.024420      0.039407      0.002018 -0.179132
# TotalMntSpent            0.364560      0.306261      0.119898  0.203087
# TotalPurchases           0.213905      0.210306      0.083021  0.124389
# TotalCmpAccepted         0.506396      0.463902      0.247354  0.709310
#
#                      Complain  Children  Year_Customer  TotalMntSpent  \
# Year_Birth          -0.008636 -0.082244      -0.020947      -0.176301
# Income              -0.032893 -0.352934       0.017776       0.860949
# Recency              0.000711  0.004379      -0.012985       0.010347
# MntWines            -0.036307 -0.322066      -0.137692       0.934235
# MntFruits           -0.008453 -0.451674      -0.115543       0.674368
# MntMeatProducts     -0.024761 -0.474348      -0.145846       0.938923
# MntFishProducts     -0.032261 -0.483417      -0.118410       0.688086
# MntSweetProducts    -0.038727 -0.449852      -0.112437       0.672558
# MntGoldProds        -0.040545 -0.299624      -0.201158       0.694881
# NumDealsPurchases    0.026147  0.545993      -0.189397       0.004234
# NumWebPurchases     -0.022387 -0.177953      -0.181682       0.747669
# NumCatalogPurchases -0.031518 -0.441382      -0.123595       0.892392
# NumStorePurchases   -0.026033 -0.336027      -0.102139       0.827730
# NumWebVisitsMonth    0.022191  0.417676      -0.278130      -0.465111
# AcceptedCmp3        -0.004823  0.010082       0.006960       0.009087
# AcceptedCmp4        -0.026367 -0.090789      -0.009778       0.244343
# AcceptedCmp5        -0.024663 -0.293254       0.024420       0.364560
# AcceptedCmp1        -0.022868 -0.239638       0.039407       0.306261
# AcceptedCmp2        -0.010893 -0.080939       0.002018       0.119898
# Response            -0.008035 -0.144124      -0.179132       0.203087
# Complain             1.000000  0.032404      -0.018597      -0.041461
# Children             0.032404  1.000000       0.032511      -0.466363
# Year_Customer       -0.018597  0.032511       1.000000      -0.168147
# TotalMntSpent       -0.041461 -0.466363      -0.168147       1.000000
# TotalPurchases      -0.020826 -0.235109      -0.179184       0.872107
# TotalCmpAccepted    -0.031767 -0.219988      -0.073707       0.361910
#
#                      TotalPurchases  TotalCmpAccepted
# Year_Birth                -0.204805         -0.009304
# Income                     0.725022          0.282750
# Recency                    0.006070         -0.107679
# MntWines                   0.859624          0.355258
# MntFruits                  0.569089          0.142075
# MntMeatProducts            0.823438          0.284925
# MntFishProducts            0.577714          0.119554
# MntSweetProducts           0.575210          0.138497
# MntGoldProds               0.637588          0.236248
# NumDealsPurchases          0.304948         -0.074654
# NumWebPurchases            0.864374          0.232858
# NumCatalogPurchases        0.824873          0.341054
# NumStorePurchases          0.894347          0.151239
# NumWebVisitsMonth         -0.309689         -0.056128
# AcceptedCmp3              -0.018628          0.465528
# AcceptedCmp4               0.208696          0.500692
# AcceptedCmp5               0.213905          0.506396
# AcceptedCmp1               0.210306          0.463902
# AcceptedCmp2               0.083021          0.247354
# Response                   0.124389          0.709310
# Complain                  -0.020826         -0.031767
# Children                  -0.235109         -0.219988
# Year_Customer             -0.179184         -0.073707
# TotalMntSpent              0.872107          0.361910
# TotalPurchases             1.000000          0.245941
# TotalCmpAccepted           0.245941          1.000000

# %%
sns.clustermap(correlation, cmap='PiYG', vmin=-1.0, vmax=1.0, center=0);

# %% [markdown]
# ##### Let us plot the 2-D scatter and line plots to better understand the correlations between them

# %% [markdown]
# * Income:
#          - TotalMntSpent, MntWines, MntMeatProducts, NumCatalogPurchases, NumStorePurchases, TotalPurchases are positively correlated with 'Income' (r >= 0.7)
#
#          - NumWebVisitsMonth is negatively correlated with 'Income' (r = -0.62)

# %%
sns.lmplot(x='Income', y='TotalMntSpent', data=mar_df)

# %%
sns.lmplot(x='Income', y='TotalPurchases', data=mar_df)

# %%
sns.lmplot(x='Income', y='NumWebVisitsMonth', data=mar_df)

# %% [markdown]
# * Children:
#
#          - NumDealsPurchases is positively correlated with 'Children'
#
#          - TotalMntSpent, MntMeatProducts, NumCatalogPurchases, MntFishProducts are negatively correlated with 'Children'

# %%
sns.lmplot(x='Children', y='NumDealsPurchases', data=mar_df)

# %%
sns.lmplot(x='Children', y='TotalMntSpent', data=mar_df)

# %%
sns.lmplot(x='Children', y='MntFishProducts', data=mar_df)

# %%
sns.lmplot(x='Children', y='NumCatalogPurchases', data=mar_df)

# %% [markdown]
# * TotalMntSpent:
#
#          - NumWebPurchases, NumStorePurchases, NumCatalogPurchases is positively correlated with 'TotalMntSpent'
#
#          - NumWebVisitsMonth, Children are negatively correlated with 'TotalMntSpent'

# %%
sns.lmplot(x='NumWebPurchases', y='TotalMntSpent', data=mar_df)

# %%
sns.lmplot(x='NumCatalogPurchases', y='TotalMntSpent', data=mar_df)

# %%
sns.lmplot(x='NumWebVisitsMonth', y='TotalMntSpent', data=mar_df)

# %%
sns.lmplot(x='Children', y='TotalMntSpent', data=mar_df)

# %% [markdown]
# * NumWebVisitsMonth:
#
#          - Children, NumDealsPurchases are positively correlated with 'NumWebVisitsMonth'
#
#          - Income, NumCatalogPurchases, TotalMntSpent are negatively correlated with 'NumWebVisitsMonth'

# %%
sns.lmplot(x='NumWebVisitsMonth', y='Income', data=mar_df)

# %%
sns.lmplot(x='NumWebVisitsMonth', y='NumCatalogPurchases', data=mar_df)

# %%
sns.lmplot(x='NumWebVisitsMonth', y='TotalMntSpent', data=mar_df)

# %%
sns.lmplot(x='NumWebVisitsMonth', y='NumStorePurchases', data=mar_df)

# %%
sns.lmplot(x='NumWebVisitsMonth', y='Children', data=mar_df)

# %%
sns.lmplot(x='NumWebVisitsMonth', y='NumDealsPurchases', data=mar_df)

# %% [markdown]
# * TotalCmpAccepted:
#
#         - Response is positively correlated with TotalCmpAccepted

# %%
sns.lmplot(x='TotalCmpAccepted', y='Response', data=mar_df)

# %% [markdown]
# ### Now, let us answer some important data analysis questions

# %% [markdown]
# ##### Q) What is the total amount spent on each product? What are the best selling and least selling products' by amount spent?

# %%
mnt_products = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 
                'MntSweetProducts', 'MntGoldProds']

# %%
print('Total amount spent on each item (in $):\n') 

for product in mnt_products:
    amnt = mar_df[product].sum()
    print(f'{product}: {amnt}')
# Out:
# Total amount spent on each item (in $):
#
# MntWines: 615819
# MntFruits: 53325
# MntMeatProducts: 324634
# MntFishProducts: 76408
# MntSweetProducts: 55164
# MntGoldProds: 88801

# %% [markdown]
# * Best selling product: Wines with \$549781
# * Least selling product: Fruits with \$49642

# %% [markdown]
# ##### Q) People from which country spent the most amount? And the least amount?

# %%
mar_df.groupby('Country')['TotalMntSpent'].sum().sort_values(ascending=False)
# Out:
# Country
# SP     603111
# SA     180920
# CA     149824
# AUS     80052
# IND     73030
# GER     64761
# US      59331
# ME       3122
# Name: TotalMntSpent, dtype: int64

# %% [markdown]
# * People from Spain (SP) spent the most amount with \$540175
# * People from Mexico (ME) spent the least amount with \$3122

# %%
mar_df.groupby('Country')['TotalMntSpent'].sum().sort_values(ascending=False).plot()
plt.ylabel('Amount Spent ($)')
# Out:
# Text(0, 0.5, 'Amount Spent ($)')

# %% [markdown]
# ##### Q3) What are the total number of purchases from each country?

# %%
mar_df.groupby('Country')['TotalPurchases'].sum().sort_values(ascending=False)
# Out:
# Country
# SP     14905
# SA      4564
# CA      3778
# AUS     2081
# IND     1979
# GER     1567
# US      1565
# ME        59
# Name: TotalPurchases, dtype: int64

# %% [markdown]
# * Spain has the most item purchases with 14060 while Mexico with the least at 59 item purchases

# %% [markdown]
# ##### Q) What is the average income of the customer in each country?

# %%
mar_df.groupby('Country')['Income'].mean().sort_values(ascending=False)
# Out:
# Country
# ME     57680.333333
# US     52709.485149
# CA     52111.016194
# SA     51588.581699
# GER    51279.346847
# AUS    51184.564626
# SP     50730.332849
# IND    48745.094891
# Name: Income, dtype: float64

# %% [markdown]
# Mexico has the highest average income (57680) while India has the least average income (48745)

# %% [markdown]
# ##### Q) What is the amount spent by each group based on their education level? Did PhD customers spent more than Graduate customers?

# %%
mar_df.groupby('Education')['TotalMntSpent'].sum().sort_values(ascending=False)
# Out:
# Education
# Graduation    628299
# PhD           286118
# Master        203655
# 2n Cycle       91662
# Basic           4417
# Name: TotalMntSpent, dtype: int64

# %% [markdown]
# Customers' with a Graduation degree spent the most amount followed by PhD Customers'. Customers' with basic degree spent the least amount.

# %% [markdown]
# ##### Q) Which group spent the most amount wrt marital status?

# %%
mar_df.groupby('Marital_Status')['TotalMntSpent'].sum().sort_values(ascending=False)
# Out:
# Marital_Status
# Married     452870
# Together    318319
# Single      256930
# Divorced    132154
# Widow        51091
# Absurd        1169
# YOLO           848
# Alone          770
# Name: TotalMntSpent, dtype: int64

# %% [markdown]
# Married group spent the most amount

# %% [markdown]
# ##### Q) Are people with no children made the most purchases than people with more children?

# %%
mar_df.groupby('Children')['TotalPurchases'].sum().sort_values(ascending=False)
# Out:
# Children
# 1    15717
# 0     9712
# 2     5069
# Name: TotalPurchases, dtype: int64

# %% [markdown]
# No. Customers' with 1 child made the most purchases followed by no children

# %% [markdown]
# ##### Q) What are the numbers of purchases made?

# %%
purchases = ['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']

# %%
for purchase in purchases:
    amnt = mar_df[purchase].sum()
    print(f'{purchase}: {amnt}')
# Out:
# NumDealsPurchases: 4801
# NumWebPurchases: 8481
# NumCatalogPurchases: 5041
# NumStorePurchases: 12175

# %% [markdown]
# * Store purchases are more than web purchases

# %% [markdown]
# ##### Q) What is the total traffic for the website?

# %%
# Total number of website visits/traffic
mar_df['NumWebVisitsMonth'].sum()
# Out:
# 11152

# %% [markdown]
# ##### Q) What is the website traffic from each country? Which country customers most visited the website?

# %%
mar_df.groupby('Country')['NumWebVisitsMonth'].sum().sort_values(ascending=False)
# Out:
# Country
# SP     5503
# SA     1648
# CA     1305
# AUS     775
# IND     759
# GER     589
# US      555
# ME       18
# Name: NumWebVisitsMonth, dtype: int64

# %% [markdown]
# * Maximum traffic is from SP (Spain) and minimum from ME (Mexico)

# %% [markdown]
# ##### Q) Which is the most successful marketing campaign based on the number of acceptances?

# %%
campaigns = ['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
             'Response']

# %%
for campn in campaigns:
    score = mar_df[campn].sum()
    print(f'{campn}: {score}')
# Out:
# AcceptedCmp1: 118
# AcceptedCmp2: 28
# AcceptedCmp3: 143
# AcceptedCmp4: 154
# AcceptedCmp5: 136
# Response: 294

# %% [markdown]
# Most successful campaign is 'Response' by number of acceptances

# %% [markdown]
# ##### Q) Which country has the most number of accepted campaigns?

# %%
mar_df.groupby('Country')['TotalCmpAccepted'].sum().sort_values(ascending=False)
# Out:
# Country
# SP     467
# SA     118
# CA     103
# GER     50
# IND     48
# AUS     47
# US      37
# ME       3
# Name: TotalCmpAccepted, dtype: int64

# %% [markdown]
# Spain (SP) has the most number of accepted campaigns with 467

# %%
mar_df.groupby('Country')['Response'].sum().sort_values(ascending=False)
# Out:
# Country
# SP     157
# SA      46
# CA      31
# AUS     19
# GER     15
# IND     12
# US      12
# ME       2
# Name: Response, dtype: int64

# %% [markdown]
# * The most successful campaign 'Response' has most number of acceptances from SP and least from ME
